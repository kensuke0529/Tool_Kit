# %%
import pandas as pd

# %%
companies_df = pd.read_json('data/snapshots/companies.json')
companies_df.head()
# Out:
#     id  order   field_6972522 field_6972523  \
# 0  132      3          X Corp
# 1  133      4  Meta Platforms
# 2  134      5       Microsoft
# 3  135      6  Bitwarden Inc.
# 4  136      7     DonorSearch
#
#                           field_6972582                field_6972584  \
# 0  7c1888b6-7e4b-47a8-9efa-780bd523dda9                https://x.com
# 1  f70799dd-3deb-4767-9eb5-6e49eeff916d       https://about.meta.com
# 2  f3886d51-bb01-4db4-aa5e-53e4b74aafa6    https://www.microsoft.com
# 3  f0f5fa7c-3647-4bb8-84b7-c7e501d54439        https://bitwarden.com
# 4  911395b3-90c3-4f8b-bfe0-f5191a8db420  https://www.donorsearch.net
#
#                                        field_6972588 field_6981499  \
# 0  [{'id': 3, 'value': 'X', 'order': '3.000000000...            []
# 1  [{'id': 4, 'value': 'Instagram', 'order': '4.0...            []
# 2  [{'id': 5, 'value': 'LinkedIn', 'order': '5.00...            []
# 3  [{'id': 7, 'value': 'Bitwarden', 'order': '7.0...            []
# 4                                                 []            []
#
#   field_7013582
# 0            []
# 1            []
# 2            []
# 3            []
# 4            []

# %%
companies_df['field_6972588'][0]
# Out:
# [{'id': 3, 'value': 'X', 'order': '3.00000000000000000000'}]

# %%
libraries_df = pd.read_json('data/snapshots/libraries.json')
libraries_df.head()
# Out:
#    id  order    field_6972530  \
# 0   1      1    Export as CSV
# 1   2      2   Export as Word
# 2  34      3    Export as PDF
# 3  35      4  Export as Excel
# 4  36      5       Import CSV
#
#                                        field_6972531  \
# 0  Exports data as .csv file -some tools also giv...
# 1  Exports data as Word file - somewhat more rare...
# 2  Exports data as PDF, fairly common option, but...
# 3  Exports data as .xlsx, sometimes with addition...
# 4  Platform allows a specialized query where the ...
#
#                  field_6972836 field_6972837 field_6972839 field_6981408  \
# 0  2026-01-28T20:47:19.072619Z            []            []            []
# 1  2026-01-28T20:47:25.269964Z            []            []            []
# 2  2026-01-28T20:47:25.710858Z            []            []            []
# 3  2026-01-28T20:47:26.143919Z            []            []            []
# 4  2026-01-27T18:36:27.619399Z            []            []            []
#
#                                        field_7001781  \
# 0                                                 []
# 1                                                 []
# 2  [{'id': 34, 'value': 'Kindsight', 'order': '34...
# 3                                                 []
# 4                                                 []
#
#                           field_7014493 field_7014495 field_7014533  \
# 0  353ac2f7-0d04-4659-b522-35ad6cc0a344            []            []
# 1  eac9324f-b73a-4c40-940d-78b4a9bda8d6            []            []
# 2  ec6ce0f6-d593-441d-92f5-e4878a47dfec            []            []
# 3  12ed96ca-ce75-41f7-a579-ba3add82c92c            []            []
# 4  ed7c43d1-f570-4d89-9ae0-681ebf002389            []            []
#
#                                        field_7025280
# 0  [{'id': 133, 'value': 'Export Options', 'order...
# 1  [{'id': 133, 'value': 'Export Options', 'order...
# 2  [{'id': 133, 'value': 'Export Options', 'order...
# 3  [{'id': 133, 'value': 'Export Options', 'order...
# 4                                                 []

# %%
tools_df = pd.read_json('data/snapshots/tools.json')
tools_df.head()
# Out:
#    id  order field_6972526 field_6972527  field_6972586  \
# 0   3    3.0             X                          0.0
# 1   4    4.0     Instagram                          0.0
# 2   5    5.0      LinkedIn                          0.0
# 3   6    6.0      Facebook                          0.0
# 4   7    7.0     Bitwarden                          0.0
#
#                                        field_6972587  \
# 0  [{'id': 132, 'value': 'X Corp', 'order': '3.00...
# 1  [{'id': 133, 'value': 'Meta Platforms', 'order...
# 2  [{'id': 134, 'value': 'Microsoft', 'order': '5...
# 3  [{'id': 133, 'value': 'Meta Platforms', 'order...
# 4  [{'id': 135, 'value': 'Bitwarden Inc.', 'order...
#
#                                        field_6972713  field_6972724  \
# 0  [{'id': 5122298, 'value': 'Social Media', 'col...            NaN
# 1  [{'id': 5122298, 'value': 'Social Media', 'col...            NaN
# 2  [{'id': 5122298, 'value': 'Social Media', 'col...            NaN
# 3  [{'id': 5122298, 'value': 'Social Media', 'col...            NaN
# 4                                                 []            0.0
#
#   field_6972725                field_6972726  \
# 0                2026-01-27T11:44:43.636443Z
# 1                2026-01-27T11:44:44.275329Z
# 2                2026-01-27T11:44:44.779554Z
# 3                2026-01-27T11:44:45.277499Z
# 4                2026-01-27T11:44:45.963823Z
#
#                           field_6972727 field_6972821 field_7001780  \
# 0  5ada842e-a40f-48dc-8bb3-f5614ec084ba            []            []
# 1  5071de5b-900c-4937-b8aa-4e999e0ec628            []            []
# 2  f0bbf170-2393-4ffa-99aa-6cbf4a7a79e8            []            []
# 3  3bcc7522-d0fb-4249-9b24-91004082806a            []            []
# 4  4f6512a2-0f98-4132-a79f-ebd82c55e4c2            []            []
#
#   field_7001840 field_7002513 field_7002514 field_7002515 field_7014254
# 0            []                          []            []            []
# 1            []                          []            []            []
# 2            []                          []            []            []
# 3            []                          []            []            []
# 4            []                          []            []            []

# %%
tools_df['field_6972587'][0]
# Out:
# [{'id': 132, 'value': 'X Corp', 'order': '3.00000000000000000000'}]

# %%
tools_df['field_6972713'][0]
# Out:
# [{'id': 5122298, 'value': 'Social Media', 'color': 'light-green'}]
